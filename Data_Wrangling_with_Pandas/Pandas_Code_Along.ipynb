# %% [markdown]
# # IPL Dataset Analysis
#
# ## Problem Statement
# We want to know as to what happens during an IPL match which raises several questions in our mind with our limited knowledge about the game called cricket on which it is based. This analysis is done to know as which factors led one of the team to win and how does it matter.

# %% [markdown]
# ## About the Dataset :
# The Indian Premier League (IPL) is a professional T20 cricket league in India contested during April-May of every year by teams representing Indian cities. It is the most-attended cricket league in the world and ranks sixth among all the sports leagues. It has teams with players from around the world and is very competitive and entertaining with a lot of close matches between teams.
#
# The IPL and other cricket related datasets are available at [cricsheet.org](https://cricsheet.org/%c2%a0(data). Feel free to visit the website and explore the data by yourself as exploring new sources of data is one of the interesting activities a data scientist gets to do.
#
# Snapshot of the data you will be working on:<br>
# <br>
# The dataset 136522 data points and 23 features<br>
#
# |Features|Description|
# |-----|-----|
# |match_code|Code pertaining to individual match|
# |date|Date of the match played|
# |city|City where the match was played|
# |venue|Stadium in that city where the match was played|
# |team1|team1|
# |team2|team2|
# |toss_winner|Who won the toss out of two teams|
# |toss_decision|toss decision taken by toss winner|
# |winner|Winner of that match between two teams|
# |win_type|How did the team won(by wickets or runs etc.)|
# |win_margin|difference with which the team won|
# |inning|inning type(1st or 2nd)|
# |delivery|ball delivery|
# |batting_team|current team on batting|
# |batsman|current batsman on strike|
# |non_striker|batsman on non-strike|
# |bowler|Current bowler|
# |runs|runs scored|
# |extras|extra run scored|
# |total|total run scored on that delivery including runs and extras|
# |extras_type|extra run scored by wides or no ball or legby|
# |player_out|player that got out|
# |wicket_kind|How did the player got out|
# |wicket_fielders|Fielder who caught out the player by catch|

# %% [markdown]
# ### Analyzing data using pandas module

# %% [markdown]
# ### Read the data using pandas module.

# %%
import pandas as pd
import numpy as np
df_ipl = pd.read_csv('./data/ipl_dataset.csv')
df_ipl.shape
# Out:
# (136522, 24)

# %%
len(df_ipl['match_code'].unique())

# You can also use: 
#df_ipl['match_code'].nunique()
# Out:
# 577

# %% [markdown]
# ### There are certain fixed cities all around the world where matches are held. Find the list of unique cities where matches were played

# %%
len(df_ipl['city'].unique()
# Out:
# 30

# %%
# Corrected as Venues to Cities
print('\nCities Played At:',df_ipl['city'].unique())
# Out:
# Cities Played At: ['East London' 'Port Elizabeth' 'Centurion' 'neutral_venue' 'Chennai'
#  'Jaipur' 'Kolkata' 'Delhi' 'Chandigarh' 'Hyderabad' 'Ranchi' 'Mumbai'
#  'Bangalore' 'Dharamsala' 'Pune' 'Rajkot' 'Durban' 'Cuttack' 'Cape Town'
#  'Ahmedabad' 'Johannesburg' 'Visakhapatnam' 'Abu Dhabi' 'Raipur' 'Kochi'
#  'Kimberley' 'Nagpur' 'Bloemfontein' 'Indore' 'Kanpur']

# %% [markdown]
# ### Find the columns which contains null values if any ?

# %%
df_ipl.isnull().sum()
# columns such as winner, win_type, win_margin, extras_type, player_out, wicket_kind, wicket_fielders are having null values.
# Out:
# match_code              0
# date                    0
# city                    0
# venue                   0
# team1                   0
# team2                   0
# toss_winner             0
# toss_decision           0
# winner               1818
# win_type             1818
# win_margin           1818
# inning                  0
# delivery                0
# batting_team            0
# batsman                 0
# non_striker             0
# bowler                  0
# runs                    0
# extras                  0
# total                   0
# extras_type        129064
# player_out         129807
# wicket_kind        129807
# wicket_fielders    131657
# dtype: int64

# %% [markdown]
# ### Though the match is held in different cities all around the world it may or maynot have multiple venues (stadiums where matches are held) list down top 5 most played venues

# %%
df_ipl.groupby('venue')['match_code'].nunique()
# Out:
# venue
# Barabati Stadium                                         7
# Brabourne Stadium                                       11
# Buffalo Park                                             3
# De Beers Diamond Oval                                    3
# Dr DY Patil Sports Academy                              17
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Dubai International Cricket Stadium                      7
# Eden Gardens                                            54
# Feroz Shah Kotla                                        53
# Green Park                                               2
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   2
# JSCA International Stadium Complex                       7
# Kingsmead                                               15
# M Chinnaswamy Stadium                                   58
# MA Chidambaram Stadium, Chepauk                         48
# Maharashtra Cricket Association Stadium                  8
# Nehru Stadium                                            5
# New Wanderers Stadium                                    8
# Newlands                                                 7
# OUTsurance Oval                                          2
# Punjab Cricket Association IS Bindra Stadium, Mohali     7
# Punjab Cricket Association Stadium, Mohali              35
# Rajiv Gandhi International Stadium, Uppal               41
# Sardar Patel Stadium, Motera                            12
# Saurashtra Cricket Association Stadium                   5
# Sawai Mansingh Stadium                                  33
# Shaheed Veer Narayan Singh International Stadium         6
# Sharjah Cricket Stadium                                  6
# Sheikh Zayed Stadium                                     7
# St George's Park                                         7
# Subrata Roy Sahara Stadium                              17
# SuperSport Park                                         12
# Vidarbha Cricket Association Stadium, Jamtha             3
# Wankhede Stadium                                        49
# Name: match_code, dtype: int64

# %%
venues = df_ipl.groupby('venue')['match_code'].nunique().sort_values(ascending=False)

# %%
print('Top 5 favoured grounds are : \n\n',venues[0:5])
# Out:
# Top 5 favoured grounds are :
#
#  venue
# M Chinnaswamy Stadium              58
# Eden Gardens                       54
# Feroz Shah Kotla                   53
# Wankhede Stadium                   49
# MA Chidambaram Stadium, Chepauk    48
# Name: match_code, dtype: int64

# %% [markdown]
# ### Make a runs vs run-count frequency table

# %%
df_ipl['runs'].value_counts()
# Out:
# 0    55870
# 1    50087
# 4    15409
# 2     8835
# 6     5806
# 3      473
# 5       42
# Name: runs, dtype: int64

# %%
# Let's look at what kind of runs were scored 
# If the frequency of sixers and fours are high then we can infer that its a high intensity match with short time period(i.e 20 overs)
runs_counts = df_ipl['runs'].value_counts()
print('Runs count frequency table:\n\n',runs_counts)

# Also you can try using pandas function crosstab
#runs_count = pd.crosstab(df_ipl['runs'], columns='runs_count')
#print('Runs count frequency table:\n\n',runs_count)
# Out:
# Runs count frequency table:
#
#  0    55870
# 1    50087
# 4    15409
# 2     8835
# 6     5806
# 3      473
# 5       42
# Name: runs, dtype: int64

# %% [markdown]
# ### IPL seasons are held every year now let's look at our data and extract how many seasons were recorded.

# %%
df_ipl['Date/Time'] = pd.to_datetime(df_ipl['date'])

# %%
year = df_ipl['Date/Time'].dt.year

# %%
type(year)
# Out:
# pandas.core.series.Series

# %%
set(year)
# Out:
# {2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016}

# %%
year.unique()
# Out:
# array([2009, 2014, 2011, 2008, 2015, 2010, 2013, 2012, 2016], dtype=int64)

# %%
df_ipl['year'] = df_ipl['date'].apply(lambda x : x[:4])

print('The no. of seasons that were played are :', len(df_ipl['year'].unique()))
print('Seasons played were in :', df_ipl['year'].unique())
# Out:
# The no. of seasons that were played are : 9
# Seasons played were in : ['2009' '2014' '2011' '2008' '2015' '2010' '2013' '2012' '2016']

# %% [markdown]
# ### What are the total no. of matches played per season

# %%
matches_per_season = df_ipl.groupby('year')['match_code'].nunique()
print('Matches held per season are :\n\n', matches_per_season)
# Out:
# Matches held per season are :
#
#  year
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# Name: match_code, dtype: int64

# %% [markdown]
# ### What are the total runs scored across each season

# %%
runs_per_season = df_ipl.groupby('year')['total'].sum()

# %%
# Seems like the season of 2012 and 2013 were most scoring seasons
print('total runs scored per season are: \n', runs_per_season)
# Out:
# total runs scored per season are:
#  year
# 2008    17936
# 2009    16320
# 2010    18862
# 2011    21154
# 2012    22451
# 2013    22541
# 2014    18909
# 2015    18331
# 2016    18862
# Name: total, dtype: int64

# %% [markdown]
# ### There are teams which are high performing and low performing. Let's look at the aspect of performance of an individual team. Filter the data and aggregate the runs scored by each team. Display top 10 results which are having runs scored over 200.

# %%
df_ipl.groupby(['match_code', 'inning','batting_team'])['total'].sum().reset_index()
# Out:
# pandas.core.frame.DataFrame

# %%
high_scores=df_ipl.groupby(['match_code', 'inning','batting_team'])['total'].sum().reset_index()

# %%
high_scores = high_scores[high_scores['total'] >= 200]

# %%
high_scores
# Out:
#       match_code  inning                 batting_team  total
# 0         335982       1        Kolkata Knight Riders    222
# 2         335983       1          Chennai Super Kings    240
# 3         335983       2              Kings XI Punjab    207
# 14        335989       1          Chennai Super Kings    208
# 15        335989       2               Mumbai Indians    202
# 16        335990       1              Deccan Chargers    214
# 17        335990       2             Rajasthan Royals    217
# 64        336014       1        Kolkata Knight Riders    204
# 74        336019       1              Kings XI Punjab    221
# 100       336033       1             Rajasthan Royals    211
# 101       336033       2          Chennai Super Kings    201
# 170       392210       1             Rajasthan Royals    211
# 232       419107       1               Mumbai Indians    212
# 233       419107       2             Rajasthan Royals    208
# 242       419112       1              Kings XI Punjab    203
# 243       419112       2  Royal Challengers Bangalore    204
# 246       419114       1               Mumbai Indians    218
# 292       419137       1          Chennai Super Kings    246
# 293       419137       2             Rajasthan Royals    223
# 296       419139       1        Kolkata Knight Riders    200
# 297       419139       2              Kings XI Punjab    204
# 398       501223       1             Delhi Daredevils    231
# 399       501223       2              Kings XI Punjab    202
# 440       501244       1  Royal Challengers Bangalore    205
# 472       501260       1              Kings XI Punjab    232
# 493       501271       1          Chennai Super Kings    205
# 519       548318       1  Royal Challengers Bangalore    205
# 520       548318       2          Chennai Super Kings    208
# 563       548342       1             Delhi Daredevils    207
# 623       548372       1  Royal Challengers Bangalore    215
# 639       548380       1          Chennai Super Kings    222
# 659       598006       1               Mumbai Indians    209
# 701       598027       1  Royal Challengers Bangalore    263
# 715       598034       1          Chennai Super Kings    200
# 749       598051       1          Chennai Super Kings    223
# 799       729283       1          Chennai Super Kings    205
# 800       729283       2              Kings XI Punjab    206
# 851       733987       1              Kings XI Punjab    231
# 871       734007       1          Sunrisers Hyderabad    205
# 872       734007       2              Kings XI Punjab    211
# 875       734011       1             Rajasthan Royals    201
# 911       734047       1              Kings XI Punjab    226
# 912       734047       2          Chennai Super Kings    202
# 914       734049       2        Kolkata Knight Riders    200
# 921       829711       1          Chennai Super Kings    209
# 947       829737       1               Mumbai Indians    209
# 971       829763       1  Royal Challengers Bangalore    200
# 992       829785       1  Royal Challengers Bangalore    226
# 994       829787       1          Sunrisers Hyderabad    201
# 1002      829795       1  Royal Challengers Bangalore    235
# 1030      829823       1               Mumbai Indians    202
# 1038      980907       1  Royal Challengers Bangalore    227
# 1118      980987       1  Royal Challengers Bangalore    248
# 1124      980993       1               Mumbai Indians    206
# 1130      980999       1  Royal Challengers Bangalore    211
# 1150      981019       1          Sunrisers Hyderabad    208
# 1151      981019       2  Royal Challengers Bangalore    200

# %%
"""
The above dataframe shows the number of times a team has scored above 200 runs against another team. 
Also the number of 200+ runs are higher in the 1st innings.
"""
high_scores.nlargest(10, 'total')
# Out:
#       match_code  inning                 batting_team  total
# 701       598027       1  Royal Challengers Bangalore    263
# 1118      980987       1  Royal Challengers Bangalore    248
# 292       419137       1          Chennai Super Kings    246
# 2         335983       1          Chennai Super Kings    240
# 1002      829795       1  Royal Challengers Bangalore    235
# 472       501260       1              Kings XI Punjab    232
# 398       501223       1             Delhi Daredevils    231
# 851       733987       1              Kings XI Punjab    231
# 1038      980907       1  Royal Challengers Bangalore    227
# 911       734047       1              Kings XI Punjab    226

# %% [markdown]
# ### Chasing a 200+ target is difficulty in T-20 format. What are the chances that a team scoring runs above 200  in their 1st inning is chased by the opposition in 2nd inning.

# %%
high_scores1 = high_scores[high_scores['inning']==1]
high_scores2 = high_scores[high_scores['inning']==2]

# %%
high_scores1.head()
# Out:
#     match_code  inning           batting_team  total
# 0       335982       1  Kolkata Knight Riders    222
# 2       335983       1    Chennai Super Kings    240
# 14      335989       1    Chennai Super Kings    208
# 16      335990       1        Deccan Chargers    214
# 64      336014       1  Kolkata Knight Riders    204

# %%
high_scores2.head()
# Out:
#      match_code  inning         batting_team  total
# 3        335983       2      Kings XI Punjab    207
# 15       335989       2       Mumbai Indians    202
# 17       335990       2     Rajasthan Royals    217
# 101      336033       2  Chennai Super Kings    201
# 233      419107       2     Rajasthan Royals    208

# %%
high_scores1=high_scores1.merge(high_scores2[['match_code','inning', 'total']], on='match_code')

# %%
high_scores1
# Out:
#     match_code  inning_x                 batting_team  total_x  inning_y  \
# 0       335983         1          Chennai Super Kings      240         2
# 1       335989         1          Chennai Super Kings      208         2
# 2       335990         1              Deccan Chargers      214         2
# 3       336033         1             Rajasthan Royals      211         2
# 4       419107         1               Mumbai Indians      212         2
# 5       419112         1              Kings XI Punjab      203         2
# 6       419137         1          Chennai Super Kings      246         2
# 7       419139         1        Kolkata Knight Riders      200         2
# 8       501223         1             Delhi Daredevils      231         2
# 9       548318         1  Royal Challengers Bangalore      205         2
# 10      729283         1          Chennai Super Kings      205         2
# 11      734007         1          Sunrisers Hyderabad      205         2
# 12      734047         1              Kings XI Punjab      226         2
# 13      981019         1          Sunrisers Hyderabad      208         2
#
#     total_y
# 0       207
# 1       202
# 2       217
# 3       201
# 4       208
# 5       204
# 6       223
# 7       204
# 8       202
# 9       208
# 10      206
# 11      211
# 12      202
# 13      200

# %%
high_scores1.rename(columns={'inning_x':'inning_1','inning_y':'inning_2','total_x':'inning1_runs','total_y':'inning2_runs'},inplace=True)

# %%
high_scores1.head()
# Out:
#    match_code  inning_1         batting_team  inning1_runs  inning_2  \
# 0      335983         1  Chennai Super Kings           240         2
# 1      335989         1  Chennai Super Kings           208         2
# 2      335990         1      Deccan Chargers           214         2
# 3      336033         1     Rajasthan Royals           211         2
# 4      419107         1       Mumbai Indians           212         2
#
#    inning2_runs
# 0           207
# 1           202
# 2           217
# 3           201
# 4           208

# %%
#high_scores1=high_scores1[high_scores1['inning1_runs']>=200]
high_scores1['is_score_chased']=1

# %%
high_scores1
# Out:
#     match_code  inning_1                 batting_team  inning1_runs  inning_2  \
# 0       335983         1          Chennai Super Kings           240         2
# 1       335989         1          Chennai Super Kings           208         2
# 2       335990         1              Deccan Chargers           214         2
# 3       336033         1             Rajasthan Royals           211         2
# 4       419107         1               Mumbai Indians           212         2
# 5       419112         1              Kings XI Punjab           203         2
# 6       419137         1          Chennai Super Kings           246         2
# 7       419139         1        Kolkata Knight Riders           200         2
# 8       501223         1             Delhi Daredevils           231         2
# 9       548318         1  Royal Challengers Bangalore           205         2
# 10      729283         1          Chennai Super Kings           205         2
# 11      734007         1          Sunrisers Hyderabad           205         2
# 12      734047         1              Kings XI Punjab           226         2
# 13      981019         1          Sunrisers Hyderabad           208         2
#
#     inning2_runs  is_score_chased
# 0            207                1
# 1            202                1
# 2            217                1
# 3            201                1
# 4            208                1
# 5            204                1
# 6            223                1
# 7            204                1
# 8            202                1
# 9            208                1
# 10           206                1
# 11           211                1
# 12           202                1
# 13           200                1

# %%
high_scores1['is_score_chased'] = np.where(high_scores1['inning1_runs']<=high_scores1['inning2_runs'], 'yes', 'no')

# %%
high_scores1
# Out:
#     match_code  inning_1                 batting_team  inning1_runs  inning_2  \
# 0       335983         1          Chennai Super Kings           240         2
# 1       335989         1          Chennai Super Kings           208         2
# 2       335990         1              Deccan Chargers           214         2
# 3       336033         1             Rajasthan Royals           211         2
# 4       419107         1               Mumbai Indians           212         2
# 5       419112         1              Kings XI Punjab           203         2
# 6       419137         1          Chennai Super Kings           246         2
# 7       419139         1        Kolkata Knight Riders           200         2
# 8       501223         1             Delhi Daredevils           231         2
# 9       548318         1  Royal Challengers Bangalore           205         2
# 10      729283         1          Chennai Super Kings           205         2
# 11      734007         1          Sunrisers Hyderabad           205         2
# 12      734047         1              Kings XI Punjab           226         2
# 13      981019         1          Sunrisers Hyderabad           208         2
#
#     inning2_runs is_score_chased
# 0            207              no
# 1            202              no
# 2            217             yes
# 3            201              no
# 4            208              no
# 5            204             yes
# 6            223              no
# 7            204             yes
# 8            202              no
# 9            208             yes
# 10           206             yes
# 11           211             yes
# 12           202              no
# 13           200              no

# %%
chased = len(high_scores1[high_scores1['is_score_chased'] == 'yes'])

# %%
print('The chances of chasing a target of 200+ in 1st innings are : {}%'.format(round(chased/14*100)))
# Out:
# The chances of chasing a target of 200+ in 1st innings are : 43%

# %%
chances = high_scores1['is_score_chased'].value_counts()
print(chances)
# Out:
# no     8
# yes    6
# Name: is_score_chased, dtype: int64

# %%
print('The chances of chasing a target of 200+ in 1st innings are : \n' , round(chances[1]/14*100))

#It seems to be clear that team batting first and scoring 200+ runs, has a very high probablity of winning the match.
# Out:
# The chances of chasing a target of 200+ in 1st innings are :
#  43.0

# %% [markdown]
# ### Every season has that one team which is outperforming others and is in great form. Which team has the highest win counts in their respective seasons ?

# %%
df_ipl.drop_duplicates(subset = 'match_code', keep='first')
# Out:
#         match_code        date            city  \
# 0           392203  2009-05-01     East London
# 253         392197  2009-04-27  Port Elizabeth
# 472         392212  2009-05-06       Centurion
# 717         729297  2014-04-23   neutral_venue
# 964         501226  2011-04-25         Chennai
# 1210        335987  2008-04-21          Jaipur
# 1451        392227  2009-05-16  Port Elizabeth
# 1693        829761  2015-05-07         Kolkata
# 1943        336005  2008-05-04          Jaipur
# 2151        501223  2011-04-23           Delhi
# 2400        419108  2010-03-13      Chandigarh
# 2646        729281  2014-04-17   neutral_venue
# 2876        501234  2011-04-30         Kolkata
# 3109        501199  2011-04-09       Hyderabad
# 3346        392213  2009-05-07       Centurion
# 3564        598061  2013-05-15          Ranchi
# 3808        501235  2011-05-01          Jaipur
# 4049        829799  2015-05-11       Hyderabad
# 4297        336020  2008-05-15           Delhi
# 4544        501210  2011-04-15          Mumbai
# 4791        501249  2011-05-09          Jaipur
# 5037        336011  2008-05-09          Jaipur
# 5260        548379  2012-05-23       Bangalore
# 5509        980945  2016-04-27           Delhi
# 5751        548374  2012-05-19      Dharamsala
# 5987        419132  2010-03-30          Mumbai
# 6238        829781  2015-05-04         Kolkata
# 6483        336013  2008-05-10         Chennai
# 6736        829733  2015-04-18            Pune
# 6967        980911  2016-04-14          Rajkot
# ...            ...         ...             ...
# 129518      501215  2011-04-18           Kochi
# 129714      734009  2014-05-14         Cuttack
# 129955      598068  2013-05-18       Bangalore
# 130055      419164  2010-04-24          Mumbai
# 130253      335995  2008-04-27      Chandigarh
# 130501      419109  2010-03-14         Kolkata
# 130744      548380  2012-05-25         Chennai
# 130973      980959  2016-05-02       Bangalore
# 131221      829791  2015-05-09         Kolkata
# 131467      392192  2009-04-25          Durban
# 131719      729295  2014-04-22   neutral_venue
# 131964      419138  2010-04-03          Mumbai
# 132202      548329  2012-05-10       Hyderabad
# 132427      501219  2011-04-20         Kolkata
# 132672      733971  2014-05-02          Ranchi
# 132878      981015  2016-05-25           Delhi
# 133122      419113  2010-03-16         Kolkata
# 133362      336035  2008-05-25         Kolkata
# 133610      501259  2011-05-16          Mumbai
# 133853      336015  2008-05-11          Jaipur
# 134098      980915  2016-04-16       Hyderabad
# 134338      419106  2010-03-12          Mumbai
# 134592      501267  2011-05-22         Kolkata
# 134840      829725  2015-04-15            Pune
# 135093      501229  2011-04-27           Kochi
# 135321      598005  2013-04-08          Jaipur
# 135563      829731  2015-04-18   Visakhapatnam
# 135810      548314  2012-04-09   Visakhapatnam
# 136053      829795  2015-05-10          Mumbai
# 136301      336018  2008-05-14          Mumbai
#
#                                                     venue  \
# 0                                            Buffalo Park
# 253                                      St George's Park
# 472                                       SuperSport Park
# 717                   Dubai International Cricket Stadium
# 964                       MA Chidambaram Stadium, Chepauk
# 1210                               Sawai Mansingh Stadium
# 1451                                     St George's Park
# 1693                                         Eden Gardens
# 1943                               Sawai Mansingh Stadium
# 2151                                     Feroz Shah Kotla
# 2400           Punjab Cricket Association Stadium, Mohali
# 2646                              Sharjah Cricket Stadium
# 2876                                         Eden Gardens
# 3109            Rajiv Gandhi International Stadium, Uppal
# 3346                                      SuperSport Park
# 3564                   JSCA International Stadium Complex
# 3808                               Sawai Mansingh Stadium
# 4049            Rajiv Gandhi International Stadium, Uppal
# 4297                                     Feroz Shah Kotla
# 4544                                     Wankhede Stadium
# 4791                               Sawai Mansingh Stadium
# 5037                               Sawai Mansingh Stadium
# 5260                                M Chinnaswamy Stadium
# 5509                                     Feroz Shah Kotla
# 5751         Himachal Pradesh Cricket Association Stadium
# 5987                                    Brabourne Stadium
# 6238                                         Eden Gardens
# 6483                      MA Chidambaram Stadium, Chepauk
# 6736              Maharashtra Cricket Association Stadium
# 6967               Saurashtra Cricket Association Stadium
# ...                                                   ...
# 129518                                      Nehru Stadium
# 129714                                   Barabati Stadium
# 129955                              M Chinnaswamy Stadium
# 130055                         Dr DY Patil Sports Academy
# 130253         Punjab Cricket Association Stadium, Mohali
# 130501                                       Eden Gardens
# 130744                    MA Chidambaram Stadium, Chepauk
# 130973                              M Chinnaswamy Stadium
# 131221                                       Eden Gardens
# 131467                                          Kingsmead
# 131719                            Sharjah Cricket Stadium
# 131964                                  Brabourne Stadium
# 132202          Rajiv Gandhi International Stadium, Uppal
# 132427                                       Eden Gardens
# 132672                 JSCA International Stadium Complex
# 132878                                   Feroz Shah Kotla
# 133122                                       Eden Gardens
# 133362                                       Eden Gardens
# 133610                         Dr DY Patil Sports Academy
# 133853                             Sawai Mansingh Stadium
# 134098          Rajiv Gandhi International Stadium, Uppal
# 134338                         Dr DY Patil Sports Academy
# 134592                                       Eden Gardens
# 134840            Maharashtra Cricket Association Stadium
# 135093                                      Nehru Stadium
# 135321                             Sawai Mansingh Stadium
# 135563  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 135810  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 136053                                   Wankhede Stadium
# 136301                                   Wankhede Stadium
#
#                               team1                        team2  \
# 0             Kolkata Knight Riders               Mumbai Indians
# 253           Kolkata Knight Riders               Mumbai Indians
# 472                 Deccan Chargers               Mumbai Indians
# 717                Rajasthan Royals          Chennai Super Kings
# 964             Chennai Super Kings                Pune Warriors
# 1210               Rajasthan Royals              Kings XI Punjab
# 1451            Chennai Super Kings               Mumbai Indians
# 1693          Kolkata Knight Riders             Delhi Daredevils
# 1943               Rajasthan Royals          Chennai Super Kings
# 2151               Delhi Daredevils              Kings XI Punjab
# 2400                Kings XI Punjab             Delhi Daredevils
# 2646               Delhi Daredevils  Royal Challengers Bangalore
# 2876          Kolkata Knight Riders              Kings XI Punjab
# 3109                Deccan Chargers             Rajasthan Royals
# 3346    Royal Challengers Bangalore             Rajasthan Royals
# 3564          Kolkata Knight Riders                Pune Warriors
# 3808               Rajasthan Royals                Pune Warriors
# 4049            Sunrisers Hyderabad              Kings XI Punjab
# 4297               Delhi Daredevils              Deccan Chargers
# 4544                 Mumbai Indians         Kochi Tuskers Kerala
# 4791               Rajasthan Royals          Chennai Super Kings
# 5037               Rajasthan Royals              Deccan Chargers
# 5260            Chennai Super Kings               Mumbai Indians
# 5509               Delhi Daredevils                Gujarat Lions
# 5751                Kings XI Punjab             Delhi Daredevils
# 5987                 Mumbai Indians              Kings XI Punjab
# 6238          Kolkata Knight Riders          Sunrisers Hyderabad
# 6483            Chennai Super Kings              Kings XI Punjab
# 6736                Kings XI Punjab        Kolkata Knight Riders
# 6967                  Gujarat Lions      Rising Pune Supergiants
# ...                             ...                          ...
# 129518         Kochi Tuskers Kerala          Chennai Super Kings
# 129714        Kolkata Knight Riders               Mumbai Indians
# 129955  Royal Challengers Bangalore          Chennai Super Kings
# 130055  Royal Challengers Bangalore              Deccan Chargers
# 130253              Kings XI Punjab             Delhi Daredevils
# 130501        Kolkata Knight Riders  Royal Challengers Bangalore
# 130744             Delhi Daredevils          Chennai Super Kings
# 130973  Royal Challengers Bangalore        Kolkata Knight Riders
# 131221        Kolkata Knight Riders              Kings XI Punjab
# 131467              Deccan Chargers               Mumbai Indians
# 131719              Kings XI Punjab          Sunrisers Hyderabad
# 131964               Mumbai Indians              Deccan Chargers
# 132202              Deccan Chargers             Delhi Daredevils
# 132427        Kolkata Knight Riders         Kochi Tuskers Kerala
# 132672          Chennai Super Kings        Kolkata Knight Riders
# 132878          Sunrisers Hyderabad        Kolkata Knight Riders
# 133122        Kolkata Knight Riders          Chennai Super Kings
# 133362        Kolkata Knight Riders              Kings XI Punjab
# 133610                Pune Warriors              Deccan Chargers
# 133853             Rajasthan Royals             Delhi Daredevils
# 134098          Sunrisers Hyderabad        Kolkata Knight Riders
# 134338              Deccan Chargers        Kolkata Knight Riders
# 134592        Kolkata Knight Riders               Mumbai Indians
# 134840              Kings XI Punjab             Delhi Daredevils
# 135093         Kochi Tuskers Kerala              Deccan Chargers
# 135321             Rajasthan Royals        Kolkata Knight Riders
# 135563          Sunrisers Hyderabad             Delhi Daredevils
# 135810              Deccan Chargers               Mumbai Indians
# 136053               Mumbai Indians  Royal Challengers Bangalore
# 136301               Mumbai Indians          Chennai Super Kings
#
#                         toss_winner toss_decision  \
# 0                    Mumbai Indians           bat
# 253                  Mumbai Indians           bat
# 472                 Deccan Chargers           bat
# 717                Rajasthan Royals         field
# 964                   Pune Warriors         field
# 1210                Kings XI Punjab           bat
# 1451                 Mumbai Indians           bat
# 1693          Kolkata Knight Riders           bat
# 1943            Chennai Super Kings           bat
# 2151                Kings XI Punjab         field
# 2400               Delhi Daredevils         field
# 2646    Royal Challengers Bangalore         field
# 2876          Kolkata Knight Riders         field
# 3109               Rajasthan Royals         field
# 3346               Rajasthan Royals         field
# 3564          Kolkata Knight Riders         field
# 3808               Rajasthan Royals         field
# 4049            Sunrisers Hyderabad           bat
# 4297                Deccan Chargers         field
# 4544           Kochi Tuskers Kerala         field
# 4791               Rajasthan Royals         field
# 5037               Rajasthan Royals         field
# 5260                 Mumbai Indians         field
# 5509               Delhi Daredevils         field
# 5751               Delhi Daredevils         field
# 5987                 Mumbai Indians         field
# 6238            Sunrisers Hyderabad         field
# 6483                Kings XI Punjab         field
# 6736          Kolkata Knight Riders         field
# 6967        Rising Pune Supergiants           bat
# ...                             ...           ...
# 129518         Kochi Tuskers Kerala         field
# 129714        Kolkata Knight Riders         field
# 129955          Chennai Super Kings         field
# 130055              Deccan Chargers           bat
# 130253             Delhi Daredevils           bat
# 130501        Kolkata Knight Riders         field
# 130744             Delhi Daredevils         field
# 130973        Kolkata Knight Riders         field
# 131221              Kings XI Punjab           bat
# 131467              Deccan Chargers           bat
# 131719          Sunrisers Hyderabad         field
# 131964               Mumbai Indians           bat
# 132202              Deccan Chargers           bat
# 132427        Kolkata Knight Riders         field
# 132672          Chennai Super Kings           bat
# 132878        Kolkata Knight Riders         field
# 133122          Chennai Super Kings           bat
# 133362              Kings XI Punjab           bat
# 133610              Deccan Chargers         field
# 133853             Rajasthan Royals         field
# 134098          Sunrisers Hyderabad           bat
# 134338              Deccan Chargers         field
# 134592               Mumbai Indians         field
# 134840              Kings XI Punjab           bat
# 135093         Kochi Tuskers Kerala         field
# 135321        Kolkata Knight Riders         field
# 135563             Delhi Daredevils           bat
# 135810              Deccan Chargers           bat
# 136053  Royal Challengers Bangalore           bat
# 136301               Mumbai Indians         field
#
#                              winner win_type  ...            bowler  runs  \
# 0                    Mumbai Indians     runs  ...          I Sharma     0
# 253                  Mumbai Indians     runs  ...          I Sharma     1
# 472                 Deccan Chargers     runs  ...        SL Malinga     0
# 717             Chennai Super Kings     runs  ...       DS Kulkarni     4
# 964             Chennai Super Kings     runs  ...       NL McCullum     0
# 1210               Rajasthan Royals  wickets  ...          MM Patel     0
# 1451            Chennai Super Kings  wickets  ...         JA Morkel     1
# 1693          Kolkata Knight Riders     runs  ...            Z Khan     0
# 1943               Rajasthan Royals  wickets  ...     Sohail Tanvir     0
# 2151               Delhi Daredevils     runs  ...           P Kumar     0
# 2400               Delhi Daredevils  wickets  ...         DP Nannes     0
# 2646    Royal Challengers Bangalore  wickets  ...          MA Starc     0
# 2876          Kolkata Knight Riders  wickets  ...             B Lee     0
# 3109               Rajasthan Royals  wickets  ...          JDP Oram     5
# 3346               Rajasthan Royals  wickets  ...           A Singh     0
# 3564                  Pune Warriors     runs  ...          L Balaji     0
# 3808               Rajasthan Royals  wickets  ...           J Botha     0
# 4049            Sunrisers Hyderabad     runs  ...    Sandeep Sharma     0
# 4297               Delhi Daredevils     runs  ...     DP Vijaykumar     2
# 4544           Kochi Tuskers Kerala  wickets  ...          RP Singh     0
# 4791            Chennai Super Kings     runs  ...        AL Menaria     4
# 5037               Rajasthan Royals  wickets  ...     Sohail Tanvir     4
# 5260            Chennai Super Kings     runs  ...   Harbhajan Singh     0
# 5509                  Gujarat Lions     runs  ...            Z Khan     4
# 5751               Delhi Daredevils  wickets  ...          M Morkel     0
# 5987                 Mumbai Indians  wickets  ...         R McLaren     0
# 6238          Kolkata Knight Riders     runs  ...           B Kumar     0
# 6483            Chennai Super Kings     runs  ...       S Sreesanth     0
# 6736          Kolkata Knight Riders  wickets  ...          UT Yadav     0
# 6967                  Gujarat Lions  wickets  ...           P Kumar     0
# ...                             ...      ...  ...               ...   ...
# 129518         Kochi Tuskers Kerala  wickets  ...          RP Singh     0
# 129714        Kolkata Knight Riders  wickets  ...          M Morkel     0
# 129955  Royal Challengers Bangalore     runs  ...          R Ashwin     0
# 130055  Royal Challengers Bangalore  wickets  ...          A Kumble     4
# 130253              Kings XI Punjab  wickets  ...             B Lee     0
# 130501        Kolkata Knight Riders  wickets  ...     CK Langeveldt     0
# 130744          Chennai Super Kings     runs  ...       Sunny Gupta     4
# 130973        Kolkata Knight Riders  wickets  ...        AD Russell     0
# 131221        Kolkata Knight Riders  wickets  ...          UT Yadav     1
# 131467              Deccan Chargers     runs  ...        SL Malinga     0
# 131719              Kings XI Punjab     runs  ...          DW Steyn     1
# 131964               Mumbai Indians     runs  ...         RG Sharma     0
# 132202             Delhi Daredevils  wickets  ...        AD Russell     0
# 132427         Kochi Tuskers Kerala     runs  ...             B Lee     0
# 132672          Chennai Super Kings     runs  ...   Shakib Al Hasan     0
# 132878          Sunrisers Hyderabad     runs  ...         YK Pathan     1
# 133122          Chennai Super Kings     runs  ...           SE Bond     0
# 133362        Kolkata Knight Riders  wickets  ...          Umar Gul     0
# 133610              Deccan Chargers  wickets  ...         JP Duminy     0
# 133853             Rajasthan Royals  wickets  ...    AD Mascarenhas     4
# 134098        Kolkata Knight Riders  wickets  ...          M Morkel     2
# 134338        Kolkata Knight Riders     runs  ...        WPUJC Vaas     0
# 134592               Mumbai Indians  wickets  ...          AN Ahmed     0
# 134840             Delhi Daredevils  wickets  ...   NM Coulter-Nile     0
# 135093              Deccan Chargers     runs  ...          RP Singh     1
# 135321             Rajasthan Royals     runs  ...             B Lee     0
# 135563             Delhi Daredevils     runs  ...           P Kumar     1
# 135810               Mumbai Indians  wickets  ...   Harbhajan Singh     0
# 136053  Royal Challengers Bangalore     runs  ...    MJ McClenaghan     0
# 136301               Mumbai Indians  wickets  ...        SM Pollock     0
#
#         extras total extras_type player_out wicket_kind  wicket_fielders  \
# 0            1     1       wides        NaN         NaN              NaN
# 253          0     1         NaN        NaN         NaN              NaN
# 472          0     0         NaN        NaN         NaN              NaN
# 717          0     4         NaN        NaN         NaN              NaN
# 964          0     0         NaN        NaN         NaN              NaN
# 1210         0     0         NaN        NaN         NaN              NaN
# 1451         0     1         NaN        NaN         NaN              NaN
# 1693         1     1       wides        NaN         NaN              NaN
# 1943         0     0         NaN   PA Patel         lbw              NaN
# 2151         0     0         NaN        NaN         NaN              NaN
# 2400         1     1       wides        NaN         NaN              NaN
# 2646         0     0         NaN        NaN         NaN              NaN
# 2876         0     0         NaN        NaN         NaN              NaN
# 3109         0     5         NaN        NaN         NaN              NaN
# 3346         0     0         NaN        NaN         NaN              NaN
# 3564         0     0         NaN        NaN         NaN              NaN
# 3808         0     0         NaN        NaN         NaN              NaN
# 4049         0     0         NaN        NaN         NaN              NaN
# 4297         0     2         NaN        NaN         NaN              NaN
# 4544         0     0         NaN        NaN         NaN              NaN
# 4791         0     4         NaN        NaN         NaN              NaN
# 5037         0     4         NaN        NaN         NaN              NaN
# 5260         0     0         NaN        NaN         NaN              NaN
# 5509         0     4         NaN        NaN         NaN              NaN
# 5751         5     5       wides        NaN         NaN              NaN
# 5987         0     0         NaN        NaN         NaN              NaN
# 6238         0     0         NaN        NaN         NaN              NaN
# 6483         0     0         NaN        NaN         NaN              NaN
# 6736         0     0         NaN        NaN         NaN              NaN
# 6967         0     0         NaN        NaN         NaN              NaN
# ...        ...   ...         ...        ...         ...              ...
# 129518       0     0         NaN        NaN         NaN              NaN
# 129714       0     0         NaN        NaN         NaN              NaN
# 129955       0     0         NaN        NaN         NaN              NaN
# 130055       0     4         NaN        NaN         NaN              NaN
# 130253       0     0         NaN        NaN         NaN              NaN
# 130501       0     0         NaN        NaN         NaN              NaN
# 130744       0     4         NaN        NaN         NaN              NaN
# 130973       0     0         NaN        NaN         NaN              NaN
# 131221       0     1         NaN        NaN         NaN              NaN
# 131467       0     0         NaN        NaN         NaN              NaN
# 131719       0     1         NaN        NaN         NaN              NaN
# 131964       1     1       wides        NaN         NaN              NaN
# 132202       0     0         NaN        NaN         NaN              NaN
# 132427       0     0         NaN        NaN         NaN              NaN
# 132672       0     0         NaN        NaN         NaN              NaN
# 132878       0     1         NaN        NaN         NaN              NaN
# 133122       0     0         NaN        NaN         NaN              NaN
# 133362       0     0         NaN        NaN         NaN              NaN
# 133610       0     0         NaN        NaN         NaN              NaN
# 133853       0     4         NaN        NaN         NaN              NaN
# 134098       0     2         NaN        NaN         NaN              NaN
# 134338       0     0         NaN  MK Tiwary      caught        RG Sharma
# 134592       0     0         NaN        NaN         NaN              NaN
# 134840       0     0         NaN        NaN         NaN              NaN
# 135093       0     1         NaN        NaN         NaN              NaN
# 135321       0     0         NaN        NaN         NaN              NaN
# 135563       0     1         NaN        NaN         NaN              NaN
# 135810       0     0         NaN        NaN         NaN              NaN
# 136053       0     0         NaN        NaN         NaN              NaN
# 136301       0     0         NaN        NaN         NaN              NaN
#
#         Date/Time  year
# 0      2009-05-01  2009
# 253    2009-04-27  2009
# 472    2009-05-06  2009
# 717    2014-04-23  2014
# 964    2011-04-25  2011
# 1210   2008-04-21  2008
# 1451   2009-05-16  2009
# 1693   2015-05-07  2015
# 1943   2008-05-04  2008
# 2151   2011-04-23  2011
# 2400   2010-03-13  2010
# 2646   2014-04-17  2014
# 2876   2011-04-30  2011
# 3109   2011-04-09  2011
# 3346   2009-05-07  2009
# 3564   2013-05-15  2013
# 3808   2011-05-01  2011
# 4049   2015-05-11  2015
# 4297   2008-05-15  2008
# 4544   2011-04-15  2011
# 4791   2011-05-09  2011
# 5037   2008-05-09  2008
# 5260   2012-05-23  2012
# 5509   2016-04-27  2016
# 5751   2012-05-19  2012
# 5987   2010-03-30  2010
# 6238   2015-05-04  2015
# 6483   2008-05-10  2008
# 6736   2015-04-18  2015
# 6967   2016-04-14  2016
# ...           ...   ...
# 129518 2011-04-18  2011
# 129714 2014-05-14  2014
# 129955 2013-05-18  2013
# 130055 2010-04-24  2010
# 130253 2008-04-27  2008
# 130501 2010-03-14  2010
# 130744 2012-05-25  2012
# 130973 2016-05-02  2016
# 131221 2015-05-09  2015
# 131467 2009-04-25  2009
# 131719 2014-04-22  2014
# 131964 2010-04-03  2010
# 132202 2012-05-10  2012
# 132427 2011-04-20  2011
# 132672 2014-05-02  2014
# 132878 2016-05-25  2016
# 133122 2010-03-16  2010
# 133362 2008-05-25  2008
# 133610 2011-05-16  2011
# 133853 2008-05-11  2008
# 134098 2016-04-16  2016
# 134338 2010-03-12  2010
# 134592 2011-05-22  2011
# 134840 2015-04-15  2015
# 135093 2011-04-27  2011
# 135321 2013-04-08  2013
# 135563 2015-04-18  2015
# 135810 2012-04-09  2012
# 136053 2015-05-10  2015
# 136301 2008-05-14  2008
#
# [577 rows x 26 columns]

# %%
# Lets see which team were performing outstanding with their respective seasons.
# drop=True - Do not try to insert index into dataframe columns
match_wise_data = df_ipl.drop_duplicates(subset = 'match_code', keep='first').reset_index(drop=True)

# %%
match_wise_data.head()
# Out:
#    match_code        date            city  \
# 0      392203  2009-05-01     East London
# 1      392197  2009-04-27  Port Elizabeth
# 2      392212  2009-05-06       Centurion
# 3      729297  2014-04-23   neutral_venue
# 4      501226  2011-04-25         Chennai
#
#                                  venue                  team1  \
# 0                         Buffalo Park  Kolkata Knight Riders
# 1                     St George's Park  Kolkata Knight Riders
# 2                      SuperSport Park        Deccan Chargers
# 3  Dubai International Cricket Stadium       Rajasthan Royals
# 4      MA Chidambaram Stadium, Chepauk    Chennai Super Kings
#
#                  team2       toss_winner toss_decision               winner  \
# 0       Mumbai Indians    Mumbai Indians           bat       Mumbai Indians
# 1       Mumbai Indians    Mumbai Indians           bat       Mumbai Indians
# 2       Mumbai Indians   Deccan Chargers           bat      Deccan Chargers
# 3  Chennai Super Kings  Rajasthan Royals         field  Chennai Super Kings
# 4        Pune Warriors     Pune Warriors         field  Chennai Super Kings
#
#   win_type  ...        bowler  runs  extras total extras_type player_out  \
# 0     runs  ...      I Sharma     0       1     1       wides        NaN
# 1     runs  ...      I Sharma     1       0     1         NaN        NaN
# 2     runs  ...    SL Malinga     0       0     0         NaN        NaN
# 3     runs  ...   DS Kulkarni     4       0     4         NaN        NaN
# 4     runs  ...   NL McCullum     0       0     0         NaN        NaN
#
#   wicket_kind  wicket_fielders  Date/Time  year
# 0         NaN              NaN 2009-05-01  2009
# 1         NaN              NaN 2009-04-27  2009
# 2         NaN              NaN 2009-05-06  2009
# 3         NaN              NaN 2014-04-23  2014
# 4         NaN              NaN 2011-04-25  2011
#
# [5 rows x 26 columns]

# %%
match_wise_data.shape
# Out:
# (577, 26)

# %%
X=match_wise_data.groupby('year')['winner'].value_counts()
X
# Out:
# year  winner
# 2008  Rajasthan Royals               13
#       Kings XI Punjab                10
#       Chennai Super Kings             9
#       Delhi Daredevils                7
#       Mumbai Indians                  7
#       Kolkata Knight Riders           6
#       Royal Challengers Bangalore     4
#       Deccan Chargers                 2
# 2009  Delhi Daredevils               10
#       Deccan Chargers                 9
#       Royal Challengers Bangalore     9
#       Chennai Super Kings             8
#       Kings XI Punjab                 7
#       Mumbai Indians                  5
#       Rajasthan Royals                5
#       Kolkata Knight Riders           3
# 2010  Mumbai Indians                 11
#       Chennai Super Kings             9
#       Deccan Chargers                 8
#       Royal Challengers Bangalore     8
#       Delhi Daredevils                7
#       Kolkata Knight Riders           7
#       Rajasthan Royals                6
#       Kings XI Punjab                 3
# 2011  Chennai Super Kings            11
#       Mumbai Indians                 10
#       Royal Challengers Bangalore    10
#       Kolkata Knight Riders           8
#       Kings XI Punjab                 7
#       Deccan Chargers                 6
#                                      ..
# 2013  Sunrisers Hyderabad             9
#       Kings XI Punjab                 8
#       Royal Challengers Bangalore     8
#       Kolkata Knight Riders           6
#       Pune Warriors                   4
#       Delhi Daredevils                3
# 2014  Kings XI Punjab                12
#       Kolkata Knight Riders          11
#       Chennai Super Kings            10
#       Mumbai Indians                  7
#       Rajasthan Royals                6
#       Sunrisers Hyderabad             6
#       Royal Challengers Bangalore     5
#       Delhi Daredevils                2
# 2015  Chennai Super Kings            10
#       Mumbai Indians                 10
#       Royal Challengers Bangalore     8
#       Kolkata Knight Riders           7
#       Rajasthan Royals                7
#       Sunrisers Hyderabad             7
#       Delhi Daredevils                5
#       Kings XI Punjab                 2
# 2016  Sunrisers Hyderabad            11
#       Gujarat Lions                   9
#       Royal Challengers Bangalore     9
#       Kolkata Knight Riders           8
#       Delhi Daredevils                7
#       Mumbai Indians                  7
#       Rising Pune Supergiants         5
#       Kings XI Punjab                 4
# Name: winner, Length: 76, dtype: int64

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
X['2008']
# Out:
# winner
# Rajasthan Royals               13
# Kings XI Punjab                10
# Chennai Super Kings             9
# Delhi Daredevils                7
# Mumbai Indians                  7
# Kolkata Knight Riders           6
# Royal Challengers Bangalore     4
# Deccan Chargers                 2
# Name: winner, dtype: int64

# %%
X['2008'].idxmax(), X['2008'].max()
# Out:
# ('Rajasthan Royals', 13)

# %%
for year in range(2008,2017):
    print(year,X[str(year)].idxmax(), X[str(year)].max())
# Out:
# 2008 Rajasthan Royals 13
# 2009 Delhi Daredevils 10
# 2010 Mumbai Indians 11
# 2011 Chennai Super Kings 11
# 2012 Kolkata Knight Riders 12
# 2013 Mumbai Indians 13
# 2014 Kings XI Punjab 12
# 2015 Chennai Super Kings 10
# 2016 Sunrisers Hyderabad 11
